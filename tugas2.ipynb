# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("=== SOAL 1====")
print("=== tamat S2====")
a = 0
b = 1
c = 4
d = 7
e = 5
f = 0
hasil = (a + b) + (c + d) + (e + f)
print("maka jumlah tingkatan SMA= "  +str(hasil))

print("=== tamat S1===")
a = 4
b = 12
c = 6
d = 13
e = 14
f = 70
hasil = (a + b) + (c + d) + (e + f)
print("maka jumlah tingkatan S2= "  +str(hasil))

print("=== tamat SMA===")
a = 12
b = 17
c = 5
d = 20
e = 11
f = 75
hasil = (a + b) + (c + d) + (e + f)
print("maka jumlah tingkatan S1= "  +str(hasil))

print("=== tamat SMP===")
a = 5
b = 6
c = 15
d = 9
e = 20
f = 15
hasil = (a + b) + (c + d) + (e + f)
print("maka jumlah tingkatan SMP= "  +str(hasil))

print("=== tamat SD===")
a = 1
b = 8
c = 0
d = 19
e = 10
f = 1
hasil = (a + b) + (c + d) + (e + f)
print("maka jumlah tingkatan SD= "  +str(hasil))

print("=== tingkatan tidak diketahui")
a = 2
b = 14
c = 3
d = 10
e = 0
f = 1
hasil = (a + b ) + (c  + d ) + (e + f)
print("maka jumlah tingkatan tidak diketahui= "  +str(hasil))


print("====soal 2===")
print("=== dilihat dari pendidikan===")
#s2
a = 17
b = 0.25
hasil = (a * b)
print("maka mutu pendidikan s2 adalah=" +str(hasil))

#s1
a = 119
b = 0.2
hasil = (a * b)
print("maka mutu pendidikan s1 adalah=" +str(hasil))

#SMA
a = 140
b = 0.15
hasil = (a * b)
print("maka mutu pendidikan SMA adalah=" +str(hasil))

#SMP
a = 70
b = 0.10
hasil = (a * b)
print("maka mutu pendidikan SMP adalah=" +str(hasil))

#SD
a = 39
b = 0.5
hasil = (a * b)
print("maka mutu pendidikan SMA adalah=" +str(hasil))

#tidak diketahu
a = 30
b = 0.3
hasil = (a * b)
print("maka mutu pendidikan SMA adalah=" +str(hasil))


print("==== soal 3===")
print("===rentang 70====")
#s2
a = 0
b = 0.25
hasil = (a * b)
print("hasil dari s2 adalah =" +str(hasil))

#s1
a = 4
b = 0.2
hasil = (a * b)
print("hasil dari S1 adalah=" +str(hasil))

#SMA
a = 12
b = 0.15
hasil = (a * b)
print("hasil dari SMA adalah=" +str(hasil))

#SMP
a = 5
b = 0.10
hasil = (a * b)
print("hasil dari SMP adalah=" +str(hasil))

#SD
a = 1
b = 0.5
hasil = (a * b)
print("hasil dari SD adalah=" +str(hasil))

#tidak diketahu
a = 2
b = 0.3
hasil = (a * b)
print("hasil dari tidak diketahui adalah=" +str(hasil))


a = 0
b = 0.8
c = 1.799999999998
d = 0.5
e = 0.5
f = 0.6

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang 70 adalah =" + str(hasil))

print("===rentang 60====")
#s2
a = 1
b = 0.25
hasil = (a * b)
print("maka mutu tamat S2 adalah=" +str(hasil))

#s1
a = 12
b = 0.2
hasil = (a * b)
print("maka mutu tamat S1 adalah=" +str(hasil))

#SMA
a = 17
b = 0.15
hasil = (a * b)
print("maka mutu tamat SMA adalah=" +str(hasil))

#SMP
a = 6
b = 0.10
hasil = (a * b)
print("maka mutu tamat SMP adalah=" +str(hasil))

#SD
a = 8
b = 0.5
hasil = (a * b)
print("maka mutu tamat SD adalah=" +str(hasil))

#tidak diketahu
a = 14
b = 0.3
hasil = (a * b)
print("maka mutu tidak diketahui adalah=" +str(hasil))


a = 0.25
b = 2.4000000000000004
c =2.55
d = 0.6000000000000001
e = 4.0
f =4.2

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang 60 adalah =" + str(hasil))


print("===rentang 50====")
#s2
a = 4
b = 0.25
hasil = (a * b)
print("maka mutu tamat  S2 adalah=" +str(hasil))

#s1
a = 6
b = 0.2
hasil = (a * b)
print("maka mutu tamat S1 adalah=" +str(hasil))

#SMA
a = 5
b = 0.15
hasil = (a * b)
print("maka mutu tamat SMA adalah=" +str(hasil))

#SMP
a = 15
b = 0.10
hasil = (a * b)
print("maka mutu tamat SMP adalah=" +str(hasil))

#SD
a = 0
b = 0.5
hasil = (a * b)
print("maka mutu tamat SD adalah=" +str(hasil))

#tidak diketahu
a = 3
b = 0.3
hasil = (a * b)
print("maka mutu tidak diketahui adalah=" +str(hasil))


a = 1.0
b = 1.2000000000000002
c = 0.75
d = 1.5
e = 0.0
f = 0.8999999999999999

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang 50 adalah =" + str(hasil))

print("===rentang 40====")
#s2
a = 7
b = 0.25
hasil = (a * b)
print("maka mutu tamat S2 adalah=" +str(hasil))

#s1
a = 13
b = 0.2
hasil = (a * b)
print("maka mutu tamat S1 adalah=" +str(hasil))

#SMA
a = 20
b = 0.15
hasil = (a * b)
print("maka mutu tamat SMA adalah=" +str(hasil))

#SMP
a = 9
b = 0.10
hasil = (a * b)
print("maka mutu tamat SD adalah=" +str(hasil))

#SD
a = 19
b = 0.5
hasil = (a * b)
print("maka mutu tamat SD adalah =" +str(hasil))

#tidak diketahu
a = 10
b = 0.3
hasil = (a * b)
print("maka mutu tamat tidak diketahui adalah=" +str(hasil))


a = 1.75
b = 2.6
c = 3.0
d = 0.9
e = 9.5
f = 3.0

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang 40 adalah =" + str(hasil))



print("===rentang 30====")
#s2
a = 5
b = 0.25
hasil = (a * b)
print("maka mutu tamat S2  adalah=" +str(hasil))

#s1
a = 14
b = 0.2
hasil = (a * b)
print("maka mutu tamat S1 adalah=" +str(hasil))

#SMA
a = 11
b = 0.15
hasil = (a * b)
print("maka mutu tamat SMA adalah=" +str(hasil))

#SMP
a = 20
b = 0.10
hasil = (a * b)
print("maka mutu tamat SMP adalah=" +str(hasil))

#SD
a = 10
b = 0.5
hasil = (a * b)
print("maka mutu tamat SDadalah=" +str(hasil))

#tidak diketahu
a = 0
b = 0.3
hasil = (a * b)
print("maka mutu tamat tidak diketahui adalah=" +str(hasil))


a = 1.25
b = 2.8000000000000003
c = 1.65
d = 2.0
e = 5.0
f = 0.0
hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang 30 adalah =" + str(hasil))


print("===rentang 20====")
#s2
a = 0
b = 0.25
hasil = (a * b)
print("maka mutu tamat S2 adalah=" +str(hasil))

#s1
a = 0
b = 0.2
hasil = (a * b)
print("maka mutu tamat S1 adalah=" +str(hasil))

#SMA
a = 75
b = 0.15
hasil = (a * b)
print("maka mutu tamat SMA adalah=" +str(hasil))

#SMP
a = 15
b = 0.10
hasil = (a * b)
print("maka mutu tamat SMP adalah =" +str(hasil))

#SD
a = 1
b = 0.5
hasil = (a * b)
print("maka mutu tamat SD adalah=" +str(hasil))

#tidak diketahu
a = 1
b = 0.3
hasil = (a * b)
print("maka mutu tamat tidak diketahui =" +str(hasil))


a = 0.0
b = 0.0
c = 11.25
d = 1.5
e = 0.5
f = 0.3
hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang 30 adalah=" + str(hasil))


print("==== SOAL 4====")
min = [4.199999999998001]

print("maka jumlah belanjaan paling kecil."+ str(min))
# Out:
# === SOAL 1====
# === tamat S2====
# maka jumlah tingkatan SMA= 17
# === tamat S1===
# maka jumlah tingkatan S2= 119
# === tamat SMA===
# maka jumlah tingkatan S1= 140
# === tamat SMP===
# maka jumlah tingkatan SMP= 70
# === tamat SD===
# maka jumlah tingkatan SD= 39
# === tingkatan tidak diketahui
# maka jumlah tingkatan tidak diketahui= 30
# ====soal 2===
# === dilihat dari pendidikan===
# maka mutu pendidikan s2 adalah=4.25
# maka mutu pendidikan s1 adalah=23.8
# maka mutu pendidikan SMA adalah=21.0
# maka mutu pendidikan SMP adalah=7.0
# maka mutu pendidikan SMA adalah=19.5
# maka mutu pendidikan SMA adalah=9.0
# ==== soal 3===
# ===rentang 70====
# hasil dari s2 adalah =0.0
# hasil dari S1 adalah=0.8
# hasil dari SMA adalah=1.7999999999999998
# hasil dari SMP adalah=0.5
# hasil dari SD adalah=0.5
# hasil dari tidak diketahui adalah=0.6
# maka hasil rentang 70 adalah =4.199999999998001
# ===rentang 60====
# maka mutu tamat S2 adalah=0.25
# maka mutu tamat S1 adalah=2.4000000000000004
# maka mutu tamat SMA adalah=2.55
# maka mutu tamat SMP adalah=0.6000000000000001
# maka mutu tamat SD adalah=4.0
# maka mutu tidak diketahui adalah=4.2
# maka hasil rentang 60 adalah =14.0
# ===rentang 50====
# maka mutu tamat  S2 adalah=1.0
# maka mutu tamat S1 adalah=1.2000000000000002
# maka mutu tamat SMA adalah=0.75
# maka mutu tamat SMP adalah=1.5
# maka mutu tamat SD adalah=0.0
# maka mutu tidak diketahui adalah=0.8999999999999999
# maka hasil rentang 50 adalah =5.35
# ===rentang 40====
# maka mutu tamat S2 adalah=1.75
# maka mutu tamat S1 adalah=2.6
# maka mutu tamat SMA adalah=3.0
# maka mutu tamat SD adalah=0.9
# maka mutu tamat SD adalah =9.5
# maka mutu tamat tidak diketahui adalah=3.0
# maka hasil rentang 40 adalah =20.75
# ===rentang 30====
# maka mutu tamat S2  adalah=1.25
# maka mutu tamat S1 adalah=2.8000000000000003
# maka mutu tamat SMA adalah=1.65
# maka mutu tamat SMP adalah=2.0
# maka mutu tamat SDadalah=5.0
# maka mutu tamat tidak diketahui adalah=0.0
# maka hasil rentang 30 adalah =12.700000000000001
# ===rentang 20====
# maka mutu tamat S2 adalah=0.0
# maka mutu tamat S1 adalah=0.0
# maka mutu tamat SMA adalah=11.25
# maka mutu tamat SMP adalah =1.5
# maka mutu tamat SD adalah=0.5
# maka mutu tamat tidak diketahui =0.3
# maka hasil rentang 30 adalah=13.55
# ==== SOAL 4====
# maka jumlah belanjaan paling kecil.[4.199999999998001]

# %%
print("====SOAL 5====")
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan= ['s2', 's1', 'SMA', 'SMP','SD', 'tidak diketahui']
hasil= [17, 119, 140, 70, 39, 30]
c= ['red', 'green', 'blue']
plt.title(" data pendidikan")
plt.bar(pendidikan, hasil, color= c)
plt.show()



import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usia =['70', '60', '50', '40','30', '20']
hasil =[4.199999999998001, 14.0, 5.35, 20.75, 12.700000000000001, 13.55 ]
c= ['red', 'green', 'blue']
plt.title(" usia")
plt.bar(usia, hasil, color= c)
plt.show()
# Out:
# ====SOAL 5====

# %%
# pe chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pendidikan= ['s2', 's1', 'SMA', 'SMP','SD', 'tidak diketahui']
hasil= [17, 119, 140, 70, 39, 30]
ax.pie(hasil,labels=pendidikan,autopct='%1.2ff%%')
plt.title("data pendidikan")
plt.show()

# pe chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
usia =['70', '60', '50', '40','30', '20']
hasil =[4.199999999998001, 14.0, 5.35, 20.75, 12.700000000000001, 13.55 ]
c= ['red', 'green', 'blue']
ax.pie(hasil,labels=usia,autopct='%1.2ff%%')
plt.title("usia")
plt.show()
